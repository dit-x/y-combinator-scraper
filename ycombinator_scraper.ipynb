# %% [markdown]
# # Project Topic: Scrape Companies Information Listed on Y-combinator
#
# ## Project Outline - (Last updated: March, 2022)
# The project objective is to scrape information of all listed companies on Y-combinator (https://ycombinator.com/companies) and perform some basic analysis on the data.
#
# ## Information to scrape
# The image below indicates the information to be scraped for analysis.
# 1. `company_name` (company's summary and tags)
# 1. `short_description` (company's summary and tags)
# 1. `tags` (company's summary and tags)
# 1. `link` (company's link)
# 1. `company_socials` (company's info)
# 1. `founded` (company's info)
# 1. `team_size` (company's info)
# 1. `location` (company's info)
# 1. `active_founders` (Founder's decription)
# 1. `about_founder` (Founder's info)
# 1. `description` (Company's description)
#
#
# <img width="1353" alt="Screenshot 2022-04-03 at 7 29 58 PM" src="https://user-images.githubusercontent.com/55639062/162624402-ed21f6f2-ab55-46e4-aa4a-58b91b093ed6.png">
#
#
# ## Output data sample
#
# <img width="1972" alt="Screenshot 2022-04-10 at 3 42 02 PM" src="https://user-images.githubusercontent.com/55639062/162624837-b2dc1d20-e0b2-44aa-9a1b-27a0ef2b3970.png">

# %% [markdown]
# ### Important Notice
# If the code breaks, the closest fix is to verify if the HTML tag in the code is still valid. If not, change the HTML tags.

# %% [markdown]
# ## Import Necessery Libraries

# %%
from __future__ import print_function
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time, re, os
from datetime import datetime as dt
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Run selenium driver
# This function handles the dynamic part of the code by scrolling the companies page till the end. After all the companies have been fetched, BeautifulSoup extracts the links to each company.
#
# `URL`: https://www.ycombinator.com/companies

# %%
def run_seleniun_and_get_page_source():
    url = 'https://www.ycombinator.com/companies'
    options = webdriver.ChromeOptions()
    options.headless = True
    try:
        path = os.getenv('CHROMEDRIVER_HOME')
        driver = webdriver.Chrome(executable_path=path, chrome_options=options)
    except Exception as e:
        driver = webdriver.Chrome(ChromeDriverManager().install())

    driver.get(url)
    time.sleep(10)

    #scroll to the end of the page
    check_page_length = 0
    try:
        ############ SCROLL TILL END PAGE ###################
        while True:
            page_len = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            time.sleep(0.5)

            if check_page_length == page_len:
                break
            check_page_length = page_len
    except:
        driver.close()

    ############ CONVERT PAGE SOURCE TO BEAUTIFUL SOUP ELEMENT ###################
    selenium_web_content = BeautifulSoup(driver.page_source, 'lxml')
    get_company_list_block = selenium_web_content.find_all('a', class_='styles-module__company___1UVnl no-hovercard') # Extract all links
    full_location_block = selenium_web_content.find_all('span', class_='styles-module__coLocation___yhKam')

    url_and_location = []
    for i in range(len(get_company_list_block)):
        location = full_location_block[i].text.strip() 
        company_url = get_company_list_block[i]['href']
        info = [company_url, location]
        url_and_location.append(info)

    lenght = len(full_location_block)

    driver.close()
    return url_and_location, lenght

# %% [markdown]
# ## Get Company's Info
#
# The master HTML tag to fetch all the company's information is `soup.find('div',  class_='space-y-3')`. This was consistent and very easy to extract.

# %%
def get_company_info(soup):
    info = {}

    summary = soup.find('div',  class_='space-y-3')
    info['company_name'] = summary.h1.text
    info['link'] = soup.find('div', class_='flex flex-row items-center leading-none px-3').a['href']
    info['short_description'] = summary.find('div',  class_='text-xl').text

    spans = summary.find_all('span',  class_='ycdc-badge')
    info['tags'] = [what.text.replace('Y Combinator Logo', '') for what in spans]
    info['description'] = soup.p.text
    info['company_socials'] = soup.find('div',  class_='space-x-2')
    
    spans = []

    i = 0
    for fact in soup.find('div', class_="space-y-0.5").find_all('span'):
        spans.append(fact.text)
        try:
            key_ = spans[i].lower().replace(' ', '_')[:-1]
            info[key_] = spans[i+1]
            i += 2
        except:
            pass

    info['company_socials'] = [a['href'] for a in soup.find('div',  class_='space-x-2').find_all('a')]

    return info

# %% [markdown]
# # Get Founder's Info
#
# This was a bit rusty as it is not consistent across all the company, some company contains more information about the founders while some do not. To understand the disparity in the information check:
# - `Airbnb` - https://www.ycombinator.com/companies/airbnb
# - `Coinbase` -  https://www.ycombinator.com/companies/coinbase
# - `Pardes Bio` - https://www.ycombinator.com/companies/pardes-bio

# %%
def get_founders_info(soup):
    founders_info = {}
    try:
        founders = soup.find('div', class_='space-y-5')
        founders_info['active_founders'] = [name.div.text for name in founders.find_all('div', class_='leading-snug')]
        about_founder = {}
        all_about = []
        for founder in founders.find_all('div', class_='leading-snug'):
            about_founder = {}
            name = founder.find('div', class_='font-bold').text

            about_founder['name'] = name

            divs = [ what for what in founder.find_all('div')]
            about_founder['role'] = divs[1].text
            about_founder['social_media_links'] = [link['href'] for link in founder.find('div', class_='mt-1 space-x-2').find_all('a')]

            all_about.append(about_founder)
        
    except:
        founders = soup.find('div', class_='space-y-4')
        founders_info['active_founders'] = [name.div.text for name in founders.find_all('div', class_='leading-snug')]
        founders_info = {}
        all_about = []
        for founder in founders.find_all('div', class_='leading-snug'):
            about_founder = {}
            name = founder.find('div', class_='font-bold').text

            about_founder['name'] = name

            divs = [ what for what in founder.find_all('div')]
            about_founder['role'] = divs[1].text
            about_founder['social_media_links'] = [link['href'] for link in founder.find('div', class_='mt-1 space-x-2').find_all('a')]

            all_about.append(about_founder)
            
    founders_info['about_founders'] = all_about
    return founders_info

# %%
def get_founders_info(soup):
    founders_info = {}
    try:
        founders = soup.find('div', class_='space-y-5')
        founders_info['active_founders'] = [name.div.text for name in founders.find_all('div', class_='leading-snug')]

        all_about = []
        for what in founders.find_all('div', class_='flex flex-row gap-3 items-start flex-col md:flex-row'):
            about_founder = {}
            name = what.h3.text
            split = name.split(', ')

            about_founder['name'] = name

            if split[0] != split[-1]:
                about_founder['role'] = split[-1]
            else:
                about_founder['role'] = ''

            about_founder['social_media_links'] = [link['href'] for link in what.find('div', class_='mt-1 space-x-2').find_all('a')]
            
            all_about.append(about_founder)

        
    except:
        founders = soup.find('div', class_='space-y-4')
        founders_info['active_founders'] = [name.div.text for name in founders.find_all('div', class_='leading-snug')]
        founders_info = {}
        all_about = []
        for founder in founders.find_all('div', class_='leading-snug'):
            about_founder = {}
            name = founder.find('div', class_='font-bold').text

            about_founder['name'] = name

            divs = [ what for what in founder.find_all('div')]
            about_founder['role'] = divs[1].text
            about_founder['social_media_links'] = [link['href'] for link in founder.find('div', class_='mt-1 space-x-2').find_all('a')]

            all_about.append(about_founder)
            
    founders_info['about_founders'] = all_about
    return founders_info

# %% [markdown]
# ## Scrape all Info
# This function put all the scrapers together i.e the company info scraper and the founder info scraper

# %%
def scrape_info(link_and_location):
    main_url = 'https://www.ycombinator.com'
    url = main_url + link_and_location[0]
    source = requests.get(url).text
    soup = BeautifulSoup(source, 'lxml')

    company_all_info = get_company_info(soup)
    company_all_info['full_location'] = link_and_location[1]
    try:
        founder_info = get_founders_info(soup)
    except:
        founder_info = {
            "active_founders":[],
            "about_founders": []
        }
    company_all_info.update(founder_info)

    return company_all_info

# %% [markdown]
# ## Save the scraped data
# This converts the scraped info to pandas and rearranges the columns

# %%
def save_to_csv(scraped_info, savepath):
       df = pd.DataFrame(scraped_info)
       df = df[['company_name', 'link', 'short_description', 'tags',
              'company_socials', 'founded', 'team_size', 'full_location', 'location',
              'active_founders', 'about_founders', 'description']]
              
       df.to_csv(savepath, index=False)

# %% [markdown]
# ## Get all links from Y-combinator

# %%
main_url = 'https://www.ycombinator.com'

start = dt.now()
url_and_location, lenght = run_seleniun_and_get_page_source()

runtime = (dt.now() - start).total_seconds()
print(f'Total scroll runtime - {runtime}')
# Out:
# /var/folders/84/yt4k0rqn11lgq7cts898myjm0000gn/T/ipykernel_69889/737915299.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=path, chrome_options=options)
# /var/folders/84/yt4k0rqn11lgq7cts898myjm0000gn/T/ipykernel_69889/737915299.py:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=path, chrome_options=options)
# Total scroll runtime - 15.207302

# %% [markdown]
# ## Scraping without multi-threading
# The script ran for `~15 mins` to scrape information from 1000 companies.
#
# `Note:` The runtime can be faster or slower depending on internet connectivity.

# %%
companies = []
retries = []
count = 1

start_no_thread = dt.now()
run = True
while run:
    for link_href in url_and_location:
        try:
            print(f"{count}/{lenght}", end='\r')
            company_all_info = scrape_info(link_href)
            companies.append(company_all_info)

        except Exception as e:
            print(e)
            retries.append(link_href)
        count += 1
    if retries != []:
        url_and_location = retries
        retries = []
    else:
        run = False
        

runtime_no_thread = (dt.now() - start_no_thread).total_seconds()
print(f'Total runtime - {runtime_no_thread}')
# Out:
# Total runtime - 38.820362

# %% [markdown]
# ## Scraping using multi-threading
# Multithreading gives a faster and more efficient result. The script ran for about `~57.5 secs` as compared to the first approach.
#
# `Note:` The runtime can be faster or slower depending on internet connectivity.

# %%
import concurrent.futures as cf


start_thread = dt.now()
m_companies = []
with cf.ThreadPoolExecutor() as exc:
    results = exc.map(scrape_info, url_and_location)

    for result in results:
        m_companies.append(result)

runtime_thread = (dt.now() - start_thread).total_seconds()
print(f'Total runtime - {runtime_thread}')
# Out:
# Total runtime - 3.564972

# %% [markdown]
# ## Save as CSV

# %%
import pandas as pd

save_to_csv(scraped_info=m_companies, savepath='ycombinator.csv')

# %%
df = pd.read_csv('ycombinator.csv')
print(df.shape)
df.head()
# Out:
# (1000, 12)
#   company_name                      link  \
# 0       Airbnb         http://airbnb.com
# 1     Coinbase  https://www.coinbase.com
# 2     DoorDash       http://doordash.com
# 3       GitLab        http://gitlab.com/
# 4      Dropbox        http://dropbox.com
#
#                                    short_description  \
# 0              Book accommodations around the world.
# 1            Buy, sell, and manage cryptocurrencies.
# 2                               Restaurant delivery.
# 3  A complete DevOps platform delivered as a sing...
# 4               Backup and share files in the cloud.
#
#                                                 tags  \
# 0         ['W09', 'Public', 'Marketplace', 'Travel']
# 1                                  ['S12', 'Public']
# 2                                  ['S13', 'Public']
# 3  ['W15', 'Public', 'DevSecOps', 'Developer Tools']
# 4                                  ['S07', 'Public']
#
#                                      company_socials  founded  team_size  \
# 0  ['https://www.linkedin.com/company/airbnb/', '...   2008.0     5000.0
# 1  ['https://twitter.com/coinbase', 'https://www....   2012.0      500.0
# 2  ['https://www.linkedin.com/company/doordash/',...      NaN     1600.0
# 3  ['https://www.linkedin.com/company/gitlab-com'...   2012.0     1200.0
# 4  ['https://www.linkedin.com/company/dropbox/', ...   2008.0     4000.0
#
#             full_location       location  \
# 0  San Francisco, CA, USA  San Francisco
# 1  San Francisco, CA, USA  San Francisco
# 2  San Francisco, CA, USA  San Francisco
# 3  San Francisco, CA, USA  San Francisco
# 4  San Francisco, CA, USA  San Francisco
#
#                                      active_founders  \
# 0  ['Nathan Blecharczyk', 'Brian Chesky', 'Joe Ge...
# 1                                ['Brian Armstrong']
# 2                                        ['Tony Xu']
# 3                            ['Dmitriy Zaporozhets']
# 4                 ['Arash Ferdowsi', 'Drew Houston']
#
#                                       about_founders  \
# 0  [{'name': 'Joe Gebbia, CPO', 'role': 'CPO', 's...
# 1  [{'name': 'Brian Armstrong', 'role': 'CEO', 's...
# 2  [{'name': 'Andy Fang', 'role': 'Founder', 'soc...
# 3  [{'name': 'Sid Sijbrandij', 'role': 'CEO', 'so...
# 4  [{'name': 'Drew Houston, CEO', 'role': 'CEO', ...
#
#                                          description
# 0  Founded in August of 2008 and based in San Fra...
# 1  Founded in June of 2012, Coinbase is a digital...
# 2  Founded in 2013, DoorDash is a San Francisco-b...
# 3  GitLab is the first single application for the...
# 4  Dropbox is building the world’s first smart wo...

# %%
url = 'https://www.ycombinator.com/companies/airbnb'
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')

# %%
info = get_founders_info(soup)

pprint(info)
# Out:
# {'about_founders': [{'name': 'Nathan Blecharczyk, CTO',
#                      'role': 'CTO',
#                      'social_media_links': ['https://twitter.com/nathanblec',
#                                             'https://www.linkedin.com/in/blecharczyk/']},
#                     {'name': 'Brian Chesky, CEO',
#                      'role': 'CEO',
#                      'social_media_links': ['https://twitter.com/bchesky']},
#                     {'name': 'Joe Gebbia, CPO',
#                      'role': 'CPO',
#                      'social_media_links': ['https://twitter.com/jgebbia']}],
#  'active_founders': ['Nathan Blecharczyk', 'Brian Chesky', 'Joe Gebbia']}

# %%
df = pd.read_csv('ycombinator.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)
df.head(1000)
# Out:
#                       company_name                                               link                                  short_description                                               tags                                    company_socials  founded  team_size                                      full_location                               location                                    active_founders                                     about_founders                                        description
# 0                           Airbnb                                  http://airbnb.com              Book accommodations around the world.         ['W09', 'Public', 'Travel', 'Marketplace']  ['https://www.linkedin.com/company/airbnb/', '...   2008.0     5000.0                             San Francisco, CA, USA                          San Francisco  ['Nathan Blecharczyk', 'Brian Chesky', 'Joe Ge...  [{'name': 'Nathan Blecharczyk, CTO', 'role': '...  Founded in August of 2008 and based in San Fra...
# 1                        Amplitude                              https://amplitude.com                    Pioneering Digital Optimization                           ['W12', 'Public', 'B2B']  ['https://www.crunchbase.com/organization/ampl...   2012.0      500.0                             San Francisco, CA, USA                          San Francisco                                 ['Spenser Skates']  [{'name': 'Curtis Liu', 'role': 'CTO', 'social...  Amplitude is the global leader in Digital Opti...
# 2                         DoorDash                                http://doordash.com                               Restaurant delivery.                                  ['S13', 'Public']  ['https://www.linkedin.com/company/doordash/',...      NaN     1600.0                             San Francisco, CA, USA                          San Francisco                                        ['Tony Xu']  [{'name': 'Andy Fang', 'role': 'Founder', 'soc...  Founded in 2013, DoorDash is a San Francisco-b...
# 3                         Coinbase                           https://www.coinbase.com            Buy, sell, and manage cryptocurrencies.                                  ['S12', 'Public']  ['https://twitter.com/coinbase', 'https://www....   2012.0      500.0                     Remote; San Francisco, CA, USA                          San Francisco                                ['Brian Armstrong']  [{'name': 'Brian Armstrong', 'role': 'CEO', 's...  Founded in June of 2012, Coinbase is a digital...
# 4                          Dropbox                                 http://dropbox.com               Backup and share files in the cloud.                                  ['S07', 'Public']  ['https://www.linkedin.com/company/dropbox/', ...   2008.0     4000.0                             San Francisco, CA, USA                          San Francisco                 ['Arash Ferdowsi', 'Drew Houston']  [{'name': 'Arash Ferdowsi', 'role': '', 'socia...  Dropbox is building the world’s first smart wo...
# 5                    Embark Trucks                            http://embarktrucks.com                          Self-driving semi trucks.           ['W16', 'Public', 'Autonomous Trucking']  ['https://www.linkedin.com/company/embarktruck...   2016.0      100.0                             San Francisco, CA, USA                          San Francisco                                 ['Alex Rodrigues']  [{'name': 'Brandon Moak', 'role': 'CTO', 'soci...  We are a San Francisco based team building sel...
# 6                  Ginkgo Bioworks                          http://ginkgobioworks.com  Our mission is to make biology easier to engin...  ['S14', 'Public', 'Synthetic Biology', 'Diagno...  ['https://www.linkedin.com/company/ginkgo-biow...   2009.0      500.0                            Boston, MA, USA; Remote                                 Boston                                  ['Reshma Shetty']  [{'name': 'Barry Canton', 'role': 'Founder', '...  Ginkgo Bioworks is the organism company. We de...
# 7                    Lucira Health                      https://www.lucirahealth.com/       Next generation infectious disease test kits                                  ['W15', 'Public']  ['https://www.linkedin.com/company/lucira-heal...      NaN       43.0                                Emeryville, CA, USA                         Emeryville, CA                               ['Debkishore Mitra']  [{'name': 'Debkishore Mitra', 'role': 'Founder...  Diassess Inc. is revolutionizing the way infec...
# 8                       MatterPort                              http://matterport.com  Turn physical objects and environments into 3D...               ['W12', 'Public', 'Computer Vision']  ['https://www.crunchbase.com/organization/matt...      NaN      201.0                                 Sunnyvale, CA, USA                          Sunnyvale, CA                                ['David Gausebeck']  [{'name': 'Matt Bell', 'role': 'Founder', 'soc...  Matterport is an immersive media technology co...
# 9                         Momentus                             https://momentus.space          The space infrastructure services company  ['S18', 'Public', 'Space Exploration', 'Solar ...  ['https://www.linkedin.com/company/momentusinc...   2017.0      125.0                               Santa Clara, CA, USA                        Santa Clara, CA                                                NaN                                                 []  Momentus is a space infrastructure services co...
# 10                       PagerDuty                               http://pagerduty.com  Real-time visibility into critical apps and se...                                  ['S10', 'Public']  ['https://www.crunchbase.com/organization/page...      NaN      775.0                             San Francisco, CA, USA                          San Francisco                                   ['Alex Solomon']  [{'name': 'Baskar Puvanathasan', 'role': 'Soft...  PagerDuty is an operations performance platfor...
# 11              Pardes Biosciences                           http://www.pardesbio.com                                   We break viruses       ['S20', 'Public', 'Therapeutics', 'Biotech']    ['https://www.linkedin.com/company/pardesbio/']   2020.0        2.0                     Remote; San Francisco, CA, USA                          San Francisco                                                NaN                                                 []  We make oral drugs to treat and prevent viral ...
# 12               Rigetti Computing                                 http://rigetti.com                   Quantum coherent supercomputing.             ['S14', 'Public', 'Quantum Computing']  ['https://www.crunchbase.com/organization/rige...      NaN       51.0                                  Berkeley, CA, USA                           Berkeley, CA                                   ['Chad Rigetti']  [{'name': 'Chad Rigetti', 'role': 'CEO', 'soci...  Rigetti Computing is building the world’s most...
# 13                           Weave                                http://getweave.com      Customer communication and payments platform.                          ['W14', 'Public', 'SaaS']  ['https://www.crunchbase.com/organization/weave']   2011.0      600.0                                      Lehi, UT, USA                               Lehi, UT                                   ['Jared Rodman']  [{'name': 'Clint Berry', 'role': 'CTO', 'socia...  As the pace of innovation continues, it is gro...
# 14                          GitLab                                 http://gitlab.com/  A complete DevOps platform delivered as a sing...  ['W15', 'Public', 'Developer Tools', 'DevSecOps']  ['https://www.linkedin.com/company/gitlab-com'...   2012.0     1200.0                     Remote; San Francisco, CA, USA                          San Francisco                            ['Dmitriy Zaporozhets']  [{'name': 'Sid Sijbrandij', 'role': 'CEO', 'so...  GitLab is the first single application for the...
# 15                          Stripe                                  http://stripe.com          Payments infrastructure for the internet.  ['S09', 'Active', 'Fintech', 'Banking as a Ser...  ['https://www.linkedin.com/company/stripe/', '...      NaN     2600.0                     San Francisco, CA, USA; Remote                          San Francisco                               ['Patrick Collison']  [{'name': 'John Collison', 'role': 'President'...  Stripe is a set of tools for building and runn...
# 16                       Instacart                          https://www.instacart.com      Same-day grocery delivery and pickup service.  ['S12', 'Active', 'E-commerce', 'Grocery', 'De...  ['https://www.linkedin.com/company/instacart/'...   2012.0     1500.0                     San Francisco, CA, USA; Remote                          San Francisco  ['Brandon Leonardo', 'Apoorva Mehta', 'Max Mul...  [{'name': 'Brandon Leonardo, Grocery Hacker', ...  Instacart is the North American leader in onli...
# 17                          Cruise                               http://getcruise.com                                 Self-driving cars.  ['W14', 'Acquired', 'Autonomous Delivery', 'Ma...  ['https://www.linkedin.com/company/getcruise/'...   2013.0     1800.0                     San Francisco, CA, USA; Remote                          San Francisco                        ['Kyle Vogt', 'Daniel Kan']  [{'name': 'Kyle Vogt, CEO', 'role': 'CEO', 'so...  Cruise is building the world’s most advanced, ...
# 18                         OpenSea                                 https://opensea.io               The world's largest NFT marketplace.  ['W18', 'Active', 'NFT', 'Crypto / Web3', 'Mar...  ['https://www.linkedin.com/company/opensea-io/...   2017.0      110.0                          Remote; New York, NY, USA                               New York                   ['Devin Finzer', 'Alex Atallah']  [{'name': 'Devin Finzer, CEO', 'role': 'CEO', ...  OpenSea is the world’s first and largest NFT m...
# 19                           Faire                             https://www.faire.com/                     A one-stop shop for wholesale.                                  ['W17', 'Active']  ['https://www.linkedin.com/company/fairewholes...      NaN      260.0                             San Francisco, CA, USA                          San Francisco                                     ['Max Rhodes']  [{'name': 'Marcelo Cortes', 'role': 'CTO', 'so...  Faire is an innovative online marketplace that...
# 20                            Brex                                    http://brex.com  The financial operating system for the next ge...                                  ['W17', 'Active']  ['https://www.linkedin.com/company/brexhq/', '...      NaN      800.0                             San Francisco, CA, USA                          San Francisco                               ['Pedro Franceschi']  [{'name': 'Henrique Dubugras', 'role': 'CEO', ...  Brex puts startups in business. We are backed ...
# 21                            Deel                          https://www.letsdeel.com/  Payroll, HR, compliance, perks, and benefits f...                       ['W19', 'Active', 'Fintech']  ['https://www.linkedin.com/company/deel', 'htt...   2018.0      600.0                     Remote; San Francisco, CA, USA                          San Francisco                                      ['Shuo Wang']  [{'name': 'Alex Bouaziz', 'role': 'CEO', 'soci...  Deel is a leading global compliance and payrol...
# 22                        Rippling                               http://rippling.com/                    Magically Simplify Your HR & IT                                  ['W17', 'Active']  ['https://www.linkedin.com/company/rippling/',...   2016.0     1000.0                     San Francisco, CA, USA; Remote                          San Francisco                                     ['Prasanna S']  [{'name': 'Parker Conrad', 'role': 'CEO', 'soc...  We’re on a mission to eliminate the administra...
# 23                          Reddit                                  http://reddit.com                     The frontpage of the internet.                                ['S05', 'Acquired']  ['https://twitter.com/reddit', 'https://www.fa...      NaN      201.0                             San Francisco, CA, USA                          San Francisco                                  ['Steve Huffman']  [{'name': 'Steve Huffman', 'role': 'CEO', 'soc...  Founded by Steve Huffman and Alexis Ohanian in...
# 24                           Gusto                                  https://gusto.com  Provides growing businesses with everything to...  ['W12', 'Active', 'B2B', 'Payroll', 'Health In...  ['https://www.linkedin.com/company/gustohq/', ...   2011.0     2000.0                     San Francisco, CA, USA; Remote                          San Francisco      ['Edward Kim', 'Tomer London', 'Josh Reeves']  [{'name': "Edward Kim, ; Empowering Gusto's En...  Launched in 2012 as ZenPayroll, Gusto serves m...
# 25                        Flexport                               https://flexport.com                     Platform for global logistics.  ['W14', 'Active', 'Supply Chain', 'SaaS', 'Log...  ['https://www.linkedin.com/company/flexport/',...   2013.0     2800.0                     San Francisco, CA, USA; Remote                          San Francisco                                  ['Ryan Petersen']  [{'name': 'Ryan Petersen', 'role': 'CEO', 'soc...  Flexport believes trade can move the human rac...
# 26                        Razorpay                               https://razorpay.com  A full stack payments and neobanking platform ...  ['W15', 'Active', 'Fintech', 'Payments', 'Neob...  ['https://www.linkedin.com/company/razorpay/',...   2015.0      700.0                       Bengaluru, KA, India; Remote                       Bengaluru, India                                 ['Harshil Mathur']  [{'name': 'Shashank Kumar', 'role': 'Founder',...  Razorpay was founded by Shashank Kumar and Har...
# 27                        Scale AI                                   http://scale.com   End-to-end solutions for the entire ML lifecycle                                  ['S16', 'Active']  ['https://www.linkedin.com/company/scaleai/', ...      NaN      440.0                     San Francisco, CA, USA; Remote                          San Francisco                                  ['Alexandr Wang']  [{'name': 'Alexandr Wang', 'role': 'CEO', 'soc...  Scale, the data infrastructure for AI, is comm...
# 28                       Benchling                               http://benchling.com  Unlocking the power of biotech with modern sof...        ['S12', 'Active', 'B2B', 'SaaS', 'Biotech']  ['https://www.linkedin.com/company/benchling/?...   2012.0      700.0                     San Francisco, CA, USA; Remote                          San Francisco                          ['Sajith Wickramasekara']  [{'name': 'Sajith Wickramasekara', 'role': 'CE...  Biotechnology is rewriting life as we know it,...
# 29                        Fivetran                                http://fivetran.com      The global leader in modern data integration                                   ['W13', 'Active']  ['https://www.linkedin.com/company/fivetran/',...   2012.0      950.0                           Oakland, CA, USA; Remote                            Oakland, CA                                  ['George Fraser']  [{'name': 'Taylor Brown', 'role': 'COO', 'soci...  Fivetran fully automated connectors sync data ...
# 30                           Rappi                               http://www.rappi.com  On-demand delivery and financial services for ...                                  ['W16', 'Active']  ['https://www.linkedin.com/company/rappi/', 'h...      NaN     2000.0                           Bogotá, Bogota, Colombia                       Bogotá, Colombia                              ['Felipe Villamarin']  [{'name': 'Simon Borrero', 'role': 'CEO', 'soc...  Rappi is a mega high growth, Series B, consume...
# 31                          Checkr                              http://www.checkr.com                    A new era of background checks.                                  ['S14', 'Active']  ['https://www.linkedin.com/company/checkr-com/...   2014.0      580.0                     San Francisco, CA, USA; Remote                          San Francisco            ['Daniel Yanisse', 'Jonathan Perichon']  [{'name': 'Daniel Yanisse, CEO', 'role': 'CEO'...  Since graduating Y Combinator in 2014, Checkr’...
# 32                          Zapier                                  http://zapier.com             The easiest way to automate your work.                   ['S12', 'Active', 'SaaS', 'B2B']  ['https://www.linkedin.com/company/zapier/', '...   2011.0      400.0                     Remote; Mountain View, CA, USA                          Mountain View      ['Wade Foster', 'Mike Knoop', 'Bryan Helmig']  [{'name': 'Wade Foster', 'role': '', 'social_m...  Founded in 2011, Zapier has helped over 1.8 mi...
# 33                          Meesho                              http://www.meesho.com  Enabling anyone in India to start a business w...                    ['S16', 'Active', 'E-commerce']  ['https://www.linkedin.com/company/meesho/', '...   2015.0     1000.0                               Bengaluru, KA, India                       Bengaluru, India                                ['Sanjeev Barnwal']  [{'name': 'Vidit Aatrey', 'role': 'CEO', 'soci...  Meesho is the largest social commerce platform...
# 34                      Monzo Bank                               http://www.monzo.com                     A bank as smart as your phone.                                         ['Active']  ['https://twitter.com/monzo', 'https://www.cru...   2015.0     2100.0            London, England, United Kingdom; Remote                 London, United Kingdom                              ['Jonas Templestein']  [{'name': 'Jonas Templestein, CTO', 'role': 'C...  YC has written a good overview of our business...
# 35                Relativity Space                         http://relativityspace.com         Building humanity’s multiplanetary future.                                  ['W16', 'Active']  ['https://www.linkedin.com/company/relativity/...   2016.0      200.0                               Los Angeles, CA, USA                        Los Angeles, CA                                      ['Tim Ellis']  [{'name': 'Tim Ellis', 'role': 'CEO', 'social_...  Relativity is building humanity’s multiplaneta...
# 36                         Whatnot                            https://www.whatnot.com      Livestream shopping platform and marketplace.     ['W20', 'Active', 'Marketplace', 'E-commerce']                    ['https://twitter.com/whatnot']   2019.0      110.0                       Remote; Los Angeles, CA, USA                        Los Angeles, CA                               ['Grant LaFontaine']  [{'name': 'Logan Head', 'role': 'Founder', 'so...  Whatnot is a livestream shopping platform and ...
# 37                         Webflow                                https://webflow.com  Professional website design and publishing pla...                          ['S13', 'Active', 'SaaS']  ['https://www.linkedin.com/company/webflow-inc...   2012.0      400.0                     San Francisco, CA, USA; Remote                          San Francisco                                  ['Vlad Magdalin']  [{'name': 'Bryant Chou', 'role': 'CTO', 'socia...  Webflow empowers designers, marketers, and ent...
# 38                     MessageBird                             http://messagebird.com  The world’s largest omnichannel communications...                                  ['S16', 'Active']  ['https://www.crunchbase.com/organization/mess...   2011.0      500.0                         Amsterdam, NH, Netherlands                 Amsterdam, Netherlands                                 ['Joey van Ommen']  [{'name': 'Bob Violier', 'role': 'CTO', 'socia...  The world’s largest omnichannel communications...
# 39                    Flock Safety                         http://www.flocksafety.com  Public safety operating system disrupting the ...  ['S17', 'Active', 'Hardware', 'SaaS', 'Machine...  ['https://www.linkedin.com/company/flock-safet...   2017.0      400.0                           Atlanta, GA, USA; Remote                            Atlanta, GA                  ['Matt Feury', 'Garrett Langley']  [{'name': 'Matt Feury, CTO', 'role': 'CTO', 's...  Flock Safety provides the first public safety ...
# 40                          Convoy                                https://convoy.com/  The world's most efficient digital freight net...                                         ['Active']  ['https://www.linkedin.com/company/convoy-inc'...   2015.0     1200.0                           Seattle, WA, USA; Remote                            Seattle, WA                  ['Grant Goodale', 'Daniel Lewis']  [{'name': 'Grant Goodale, CTO', 'role': 'CTO',...  Convoy is the nation's leading digital freight...
# 41                  EquipmentShare                     https://www.equipmentshare.com     Cloud solutions for the construction industry.                                  ['W15', 'Active']  ['https://www.linkedin.com/company/equipmentsh...   2014.0     1900.0                          Columbia, MO, USA; Remote                           Columbia, MO                                   ['Brad Siegler']  [{'name': 'Jeff Lowe', 'role': 'Founder', 'soc...  EquipmentShare delivers cloud solutions for th...
# 42                      GOAT Group                              https://www.goat.com/  Platform for the greatest products from the pa...                   ['W11', 'Active', 'Marketplace']  ['https://www.linkedin.com/company/goat---snea...   2015.0      650.0                       Los Angeles, CA, USA; Remote                        Los Angeles, CA                                 ['Daishin Sugano']  [{'name': 'Eddy Lu', 'role': 'Founder', 'socia...  Operating two distinct brands – GOAT, the glob...
# 43                          Retool                                 https://retool.com                         Build internal tools fast.                                  ['W17', 'Active']    ['https://www.linkedin.com/company/tryretool/']      NaN       40.0                             San Francisco, CA, USA                          San Francisco                                      ['David Hsu']  [{'name': 'David Hsu', 'role': 'CEO', 'social_...    Retool is the fast way to build internal tools.
# 44                      GrubMarket                              http://grubmarket.com       Delivers direct from the⁣ farm to your door.                                  ['W15', 'Active']  ['https://twitter.com/facebook', 'https://www....      NaN      200.0                             San Francisco, CA, USA                          San Francisco                                        ['Mike Xu']  [{'name': 'Mike Xu', 'role': 'CEO, , President...  GrubMarket's mission is to conveniently make f...
# 45                         Segment                                 http://segment.com  Software and APIs to collect, clean, and contr...                 ['S11', 'Acquired', 'SaaS', 'B2B']  ['https://www.linkedin.com/company/segment-io/...   2011.0      550.0                     San Francisco, CA, USA; Remote                          San Francisco          ['Calvin French-Owen', 'Ilya Volodarsky']  [{'name': 'Calvin French-Owen', 'role': '', 's...  Segment is one place to collect customer data ...
# 46                        Ironclad                             http://ironcladapp.com    Digital contracting platform for legal teams.               ['S15', 'Active', 'LegalTech', 'SaaS']  ['https://www.linkedin.com/company/ironclad-in...   2014.0      400.0                     San Francisco, CA, USA; Remote                          San Francisco                                    ['Cai GoGwilt']  [{'name': 'Jason Boehmig', 'role': 'CEO', 'soc...  Contracts are business decisions trapped in ad...
# 47                     Flutterwave                            https://flutterwave.com  Helping businesses make and accept payments fr...                       ['S16', 'Active', 'Fintech']  ['https://www.linkedin.com/company/flutterwave...   2015.0      400.0                         Lagos, LA, Nigeria; Remote                         Lagos, Nigeria                           ['Olugbenga GB Agboola']  [{'name': 'ACA Adekoya', 'role': 'Founder', 's...  At Flutterwave, we are on a mission to build p...
# 48                          Podium                                 https://podium.com  An interaction and payments platform for local...        ['W16', 'Active', 'SaaS', 'B2B', 'Fintech']  ['https://www.linkedin.com/company/podium/', '...   2014.0      830.0                              Lehi, UT, USA; Remote                               Lehi, UT                      ['Dennis Steele', 'Eric Rea']  [{'name': 'Dennis Steele', 'role': '', 'social...  Podium is a suite of messaging tools for local...
# 49                          Xendit                             https://www.xendit.co/  Provides payment infrastructure for Indonesia ...           ['S15', 'Active', 'Fintech', 'Payments']  ['https://www.linkedin.com/company/xendit/', '...   2015.0      250.0                Jakarta, Jakarta, Indonesia; Remote                     Jakarta, Indonesia                                       ['Moses Lo']  [{'name': 'Bo Chen', 'role': 'CTO', 'social_me...  Xendit provides payment solutions that simplif...
# 50                           Groww                                   https://groww.in       Investing made simple for everyone in India.                                  ['W18', 'Active']  ['https://twitter.com/_groww', 'https://www.fa...      NaN       50.0                               Bengaluru, KA, India                       Bengaluru, India                                   ['Neeraj Singh']  [{'name': 'Ishan Bansal', 'role': 'Founder', '...  Groww offers a new way of investing money.\r\n...
# 51                       Outschool                               http://outschool.com  A live online learning platform that empowers ...      ['W16', 'Active', 'Education', 'Marketplace']  ['https://www.linkedin.com/company/outschool/'...   2015.0      140.0                     Remote; San Francisco, CA, USA                          San Francisco                                    ['Amir Nathoo']  [{'name': 'Nicholas Grandy', 'role': 'Founder'...  Outschool is an online learning platform that ...
# 52                         Lattice                                https://lattice.com           Modern performance management software.                                   ['W16', 'Active']  ['https://www.linkedin.com/company/lattice-hq/...   2015.0      540.0                     San Francisco, CA, USA; Remote                          San Francisco                                    ['Jack Altman']  [{'name': 'Jack Altman', 'role': 'CEO', 'socia...  Lattice is people success software that empowe...
# 53                   Helion Energy                            http://helionenergy.com                                    First to Fusion      ['S14', 'Active', 'Fusion Energy', 'Climate']  ['https://www.linkedin.com/company/helion-ener...   2013.0       54.0                                   Everett, WA, USA                            Everett, WA                                     ['Chris Pihl']  [{'name': 'David Kirtley', 'role': 'CEO', 'soc...  Helion is creating the world’s first fusion po...
# 54                      GoCardless                              http://gocardless.com   The first global network for recurring payments.                       ['S11', 'Active', 'Fintech']  ['https://twitter.com/GoCardless', 'https://ww...   2011.0      400.0            London, England, United Kingdom; Remote                 London, United Kingdom               ['Matt Robinson', 'Hiroki Takeuchi']  [{'name': 'Matt Robinson, CEO', 'role': 'CEO',...  GoCardless is on a mission to take the pain ou...
# 55                         Algolia                             http://www.algolia.com  A developer-friendly and enterprise-grade sear...  ['W14', 'Active', 'Developer Tools', 'SaaS', '...  ['https://www.linkedin.com/company/algolia/', ...   2012.0      350.0                     San Francisco, CA, USA; Remote                          San Francisco            ['Nicolas Dessaigne', 'Julien Lemoine']  [{'name': 'Nicolas Dessaigne, CEO', 'role': 'C...  Our mission is to make every search interactio...
# 56                        Newfront                          https://www.newfront.com/                        Modern insurance brokerage.          ['W18', 'Active', 'Insurance', 'Fintech']      ['https://www.linkedin.com/company/newfront']   2017.0      750.0                     San Francisco, CA, USA; Remote                          San Francisco                                 ['Gordon Wintrob']  [{'name': 'Spike Lipkin', 'role': 'CEO', 'soci...  Newfront is transforming the delivery of risk ...
# 57                         Solugen                               https://solugen.com/              Decarbonizing the chemicals industry.                       ['W17', 'Active', 'Climate']  ['https://www.linkedin.com/company/solugen/', ...      NaN      150.0                                   Houston, TX, USA                            Houston, TX                                      ['Sean Hunt']  [{'name': 'Gaurab Chakrabarti', 'role': 'Found...  Solugen has developed a unique process for the...
# 58                             Go1                                    https://go1.com  A learning platform that enables you to train ...                                  ['S15', 'Active']  ['https://www.linkedin.com/company/go1/', 'htt...   2015.0      200.0                     San Francisco, CA, USA; Remote                          San Francisco                                        ['Vu Tran']  [{'name': 'Andrew Barnes', 'role': 'CEO', 'soc...  In today’s environment, employees need trainin...
# 59                          Docker                                  http://docker.com               App store for server configurations.                                  ['S10', 'Active']  ['https://www.crunchbase.com/organization/dock...      NaN      201.0                             San Francisco, CA, USA                          San Francisco                                  ['Solomon Hykes']  [{'name': 'Solomon Hykes', 'role': 'CEO', 'soc...  Docker is the world’s leading software contain...
# 60                          Jeeves                           http://www.tryjeeves.com  International banking infrastructure for globa...                                  ['S20', 'Active']                                                 []   2019.0        NaN                             Remote; Miami, FL, USA                              Miami, FL                                ['Dileep Thazhmon']  [{'name': 'Dileep Thazhmon', 'role': '', 'soci...  Jeeves is an all-in-one corporate spend and ex...
# 61                 Modern Treasury                     http://www.moderntreasury.com/       Payment operations tools for money movement.                ['S18', 'Active', 'API', 'Fintech']  ['https://www.linkedin.com/company/modern-trea...   2018.0      160.0                     San Francisco, CA, USA; Remote                          San Francisco  ['Matt Marcus', 'Sam Aarons', 'Dimitri Dadiomov']  [{'name': 'Matt Marcus', 'role': '', 'social_m...  Modern Treasury offers tools that automate the...
# 62                         Vetcove                            https://www.vetcove.com           Powering the animal health supply chain.  ['S16', 'Active', 'Healthcare', 'Marketplace',...  ['https://www.linkedin.com/company/vetcove', '...   2015.0       52.0                             Remote; Miami, FL, USA                              Miami, FL                                 ['Mitchell Kates']  [{'name': 'Alexander Kates', 'role': 'CEO', 's...  Vetcove is how veterinarians buy the supplies ...
# 63                         ShipBob                                 http://shipbob.com  Providing Amazon level logistics to e-commerce...                                  ['S14', 'Active']  ['https://www.crunchbase.com/organization/ship...   2014.0      150.0                           Chicago, IL, USA; Remote                            Chicago, IL                                   ['Dhruv Saxena']  [{'name': 'Divey Gulati', 'role': 'Founder', '...  Founded in 2014 and based in Chicago, ShipBob ...
# 64                       Opentrons                               http://opentrons.com                    We make robots for biologists.                                   ['W16', 'Active']  ['https://twitter.com/opentrons_', 'https://ww...      NaN       80.0                                  New York, NY, USA                               New York                                      ['Chiu Chau']  [{'name': 'Will Canine', 'role': 'CPO', 'socia...  Today, biologists spend too much time pipettin...
# 65                            Sift                                  https://sift.com/     Digital trust and safety suite for businesses.  ['S11', 'Active', 'Machine Learning', 'SaaS', ...  ['https://www.crunchbase.com/organization/sift...   2011.0      405.0                     San Francisco, CA, USA; Remote                          San Francisco                                      ['Jason Tan']  [{'name': 'Jason Tan, Executive Chairman', 'ro...  Sift Science is a Series E company that facili...
# 66                            Wave                                   https://wave.com                        Mobile money app for Africa                                  ['W12', 'Active']  ['https://www.linkedin.com/in/ginikanwa-mgba-o...   2015.0      800.0               Remote; Dakar, Dakar Region, Senegal                         Dakar, Senegal                   ['Drew Durbin', 'Lincoln Quirk']  [{'name': 'Drew Durbin, CEO', 'role': 'CEO', '...  Building extremely affordable financial infras...
# 67                           Front                                  https://front.com      Collaborative hub for customer communication.                          ['S14', 'Active', 'SaaS']  ['https://www.linkedin.com/company/front-app/'...   2013.0      200.0                             San Francisco, CA, USA                          San Francisco                                 ['Laurent Perrin']  [{'name': 'Mathilde Colin', 'role': 'CEO', 'so...  Front powers the heart of business — the meani...
# 68                           Vanta                                  https://vanta.com    Automated security and compliance for startups.  ['W18', 'Active', 'Security', 'Compliance', 'B...  ['https://www.linkedin.com/company/vanta-secur...   2017.0      275.0                     San Francisco, CA, USA; Remote                          San Francisco                             ['Christina Cacioppo']  [{'name': 'Christina Cacioppo', 'role': 'CEO',...  Vanta is on a mission to protect consumer data...
# 69                        Truepill                              https://truepill.com/           API-connected healthcare infrastructure.      ['S17', 'Active', 'Consumer Health Services']  ['https://twitter.com/truepill_rx', 'https://w...   2017.0      700.0                         Remote; San Mateo, CA, USA                          San Mateo, CA                                ['Sid Viswanathan']  [{'name': 'Umar Afridi', 'role': 'Founder', 's...  Our API-connected healthcare infrastructure em...
# 70                            Pave                                   https://pave.com  Plan, communicate, and benchmark your compensa...            ['S20', 'Active', 'HR Tech', 'Fintech']  ['https://www.linkedin.com/company/pave-comp',...   2019.0      150.0  San Francisco, CA, USA; New York, NY, USA; Remote                          San Francisco                                  ['Matt Schulman']  [{'name': 'Matt Schulman', 'role': '', 'social...  Pave allows you to make smarter comp decisions...
# 71                      Prometheus                     http://www.prometheusfuels.com  We use solar and wind power to make zero net c...     ['W19', 'Active', 'Energy Storage', 'Climate']  ['https://www.linkedin.com/company/prometheusf...   2018.0       25.0                        Santa Cruz, CA, USA; Remote                         Santa Cruz, CA                                   ['Rob McGinnis']  [{'name': 'Rob McGinnis, CEO', 'role': 'CEO', ...  We remove CO2 and water from the air and use e...
# 72                             Mux                                     http://mux.com                        APIs to build better video.                                  ['W16', 'Active']  ['https://twitter.com/muxhq', 'https://www.cru...      NaN       65.0                     San Francisco, CA, USA; Remote                          San Francisco  ['Adam Brown', 'Jon Dahl', 'Steve Heffernan', ...  [{'name': 'Adam Brown', 'role': '', 'social_me...  Mux is an API-first video platform designed by...
# 73                          Jasper                                  https://jasper.ai  Jasper is a leader in creating content using A...  ['W18', 'Active', 'Artifical Intelligence', 'N...  ['http://www.linkedin.com/company/heyjasperai'...   2021.0      130.0                            Austin, TX, USA; Remote                             Austin, TX     ['Chris Hull', 'JP Morgan', 'Dave Rogenmoser']  [{'name': 'Chris Hull, Vice President of Custo...  Jasper is trained to write original, creative ...
# 74                         Athelas                                 http://athelas.com              #1 Remote Patient Monitoring Platform  ['S16', 'Active', 'Healthcare', 'Health Tech',...  ['https://www.linkedin.com/company/athelas/', ...   2016.0      160.0                     Mountain View, CA, USA; Remote                          Mountain View                                   ['Tanay Tandon']  [{'name': 'Deepika Bodapati', 'role': 'Founder...  At Athelas, we're bringing simple, life-changi...
# 75                        Snapdocs                                http://snapdocs.com            Snapdocs digitizes real estate closings        ['W14', 'Active', 'SaaS', 'Housing', 'B2B']  ['https://www.linkedin.com/company/snapdocs', ...   2014.0      520.0                     San Francisco, CA, USA; Remote                          San Francisco                                     ['Aaron King']  [{'name': 'Aaron King', 'role': 'CEO', 'social...  Snapdocs powers homeownership. Using technolog...
# 76                        EasyPost                                http://easypost.com       The shipping infrastructure of the internet.                                  ['S13', 'Active']  ['https://www.crunchbase.com/organization/easy...      NaN       51.0                     Remote; San Francisco, CA, USA                          San Francisco                               ['Jarrett Streebin']  [{'name': 'Jarrett Streebin', 'role': 'Title',...  EasyPost is the missing API that makes it quic...
# 77                          Apollo                          http://apollographql.com/  Apollo helps engineering teams accelerate deli...  ['S11', 'Active', 'Developer Tools', 'Open Sou...  ['https://www.linkedin.com/company/apollo-grap...   2012.0      200.0                     Remote; San Francisco, CA, USA                          San Francisco                                  ['Geoff Schmidt']  [{'name': 'Matt DeBergalis', 'role': 'Vice Pre...  Apollo GraphQL is the leader in open source an...
# 78                         Mashgin                                 http://mashgin.com               Self-Checkout using Computer Vision.  ['W15', 'Active', 'Computer Vision', 'Artifica...  ['https://www.linkedin.com/company/mashgin/', ...      NaN       45.0                         Palo Alto, CA, USA; Remote                              Palo Alto                             ['Abhinai Srivastava']  [{'name': 'Mukul Dhankhar', 'role': 'Founder',...  Mashgin creates better experiences through vis...
# 79                        NimbleRx                                http://nimblerx.com                   On-demand prescription delivery.                                  ['W15', 'Active']  ['https://www.crunchbase.com/organization/nimb...      NaN       51.0                                Menlo Park, CA, USA                         Menlo Park, CA                                   ['Talha Sattar']  [{'name': 'Talha Sattar', 'role': 'CEO', 'soci...  Nimble is building the largest, most convenien...
# 80                          Veriff                                https://veriff.com/  Highly-automated online identity verification ...               ['W18', 'Active', 'Fintech', 'SaaS']  ['https://www.linkedin.com/company/veriff/', '...   2015.0      350.0             Tallinn, Harju County, Estonia; Remote                       Tallinn, Estonia                                  ['Kaarel Kotkas']  [{'name': 'Janer Gorohhov', 'role': 'COO', 'so...  Veriff is a global online identity verificatio...
# 81                         Airbyte                                 https://airbyte.io                         Open-source EL(T) platform              ['W20', 'Active', 'Data Engineering']  ['https://www.linkedin.com/company/airbytehq/'...   2020.0       15.0                     San Francisco, CA, USA; Remote                          San Francisco                  ['John Lafleur', 'Michel Tricot']  [{'name': 'John Lafleur', 'role': '', 'social_...  Airbyte is an open-source data integration pla...
# 82                            Papa                               https://www.papa.com             One-stop-shop for flexible family care  ['S18', 'Active', 'Consumer Health Services', ...  ['https://www.linkedin.com/company/10879786', ...   2017.0      350.0                             Miami, FL, USA; Remote                              Miami, FL              ['Andrew Parker', 'Alfredo Vaamonde']  [{'name': 'Andrew Parker, CEO', 'role': 'CEO',...  Papa is a one-stop-shop for flexible family ca...
# 83                   Salt Security                             https://salt.security/  Protects organizations from getting breached t...                                  ['W16', 'Active']  ['https://www.crunchbase.com/organization/salt...   2016.0      170.0                                 Palo Alto, CA, USA                              Palo Alto                                   ['Roey Eliyahu']  [{'name': 'Roey Eliyahu', 'role': 'CEO', 'soci...  Salt Security protects the APIs that form the ...
# 84                        Astranis                            http://www.astranis.com        The next generation of internet satellites.                                  ['W16', 'Active']  ['https://www.linkedin.com/company/astranis/',...      NaN      100.0                             San Francisco, CA, USA                          San Francisco                   ['John Gedmark', 'Ryan McLinko']  [{'name': 'John Gedmark, CEO', 'role': 'CEO', ...                                                NaN
# 85                Clipboard Health                         http://clipboardhealth.com  Connects healthcare facilities with nurses nea...                                  ['W17', 'Active']  ['https://www.crunchbase.com/organization/clip...      NaN      500.0                                             Remote                          San Francisco                                       ['Wei Deng']  [{'name': 'Wei Deng, CEO', 'role': 'CEO', 'soc...  Clipboard Health is a marketplace where nurses...
# 86                     CoinTracker                         https://www.cointracker.io  The gold standard in cryptocurrency portfolio ...  ['W18', 'Active', 'SaaS', 'Consumer', 'Crypto ...  ['https://www.linkedin.com/company/cointracker...   2017.0       55.0                     Remote; San Francisco, CA, USA                          San Francisco                                  ['Chandan Lodha']  [{'name': 'Jon Lerner', 'role': 'Founder', 'so...  CoinTracker (https://www.cointracker.io) is a ...
# 87                        Truebill                           https://www.truebill.com                      Live your best financial life                     ['W16', 'Acquired', 'Fintech']  ['https://www.linkedin.com/company/truebill', ...   2015.0      110.0                     San Francisco, CA, USA; Remote                          San Francisco  ['Yahya Mokhtarzada', 'Haroon Mokhtarzada', 'I...  [{'name': 'Yahya Mokhtarzada, CEO', 'role': 'C...  Truebill is a leading personal finance app tha...
# 88                     CaptivateIQ                        https://www.captivateiq.com  A no-code SaaS solution to manage and track sa...                          ['W18', 'Active', 'SaaS']  ['https://www.linkedin.com/company/captivateiq...   2017.0      120.0                     San Francisco, CA, USA; Remote                          San Francisco                                    ['Hubert Wong']  [{'name': 'Mark Schopmeyer', 'role': 'CEO', 's...  CaptivateIQ is on a journey to modernize the w...
# 89                       ClassDojo                           http://www.classdojo.com  Community and collaboration platform for K-8 s...   ['IK12', 'Active', 'Education', 'Entertainment']  ['https://www.linkedin.com/company/classdojo',...   2011.0       65.0                     San Francisco, CA, USA; Remote                          San Francisco                                       ['Liam Don']  [{'name': 'Sam Chaudhary', 'role': 'CEO', 'soc...  ClassDojo is a consumer internet company on a ...
# 90                             Gem                               https://www.gem.com/                The platform for modern recruiting.     ['S17', 'Active', 'B2B', 'SaaS', 'Recruiting']  ['https://www.linkedin.com/company/gem-recruit...   2017.0      254.0                             San Francisco, CA, USA                          San Francisco                   ['Steven Bartel', 'Nick Bushak']  [{'name': 'Steven Bartel, CEO', 'role': 'CEO',...  Gem’s mission is to help companies hire great ...
# 91                             Zip                                 https://ziphq.com/                            The future of B2B spend                                  ['S20', 'Active']                                                 []   2020.0       90.0                     San Francisco, CA, USA; Remote                          San Francisco                      ['Lu Cheng', 'Rujul Zaparde']  [{'name': 'Lu Cheng', 'role': '', 'social_medi...                                                NaN
# 92                   Modern Health                      https://www.modernhealth.com/   A mental health benefits platform for employers.                                  ['W18', 'Active']  ['https://www.linkedin.com/company/modern-heal...      NaN      140.0                     San Francisco, CA, USA; Remote                          San Francisco                                  ['Alyson Watson']  [{'name': 'Alyson Watson, CEO', 'role': 'CEO',...  Modern Health is the leading mental wellness p...
# 93                        Teleport                             https://goteleport.com  The easiest, most secure way to access all you...  ['S15', 'Active', 'DevSecOps', 'Developer Tool...  ['https://www.linkedin.com/company/goteleport/...   2015.0      160.0                           Oakland, CA, USA; Remote                            Oakland, CA  ['Alexander Klizhentas', 'Taylor Wakefield', '...  [{'name': 'Alexander Klizhentas, CTO', 'role':...  Our open source products provide a Unified Acc...
# ...
# 969                       Livedocs                               https://livedocs.com            No-code analytics tool for modern teams  ['W22', 'Active', 'SaaS', 'Analytics', 'Produc...                 ['https://twitter.com/livedocshq']   2020.0        3.0                     Remote; San Francisco, CA, USA                          San Francisco                                 ['Arsalan Bashir']  [{'name': 'Arsalan Bashir', 'role': '', 'socia...  Livedocs is a no-code analytics tool for moder...
# 970                          voize                                  https://voize.de/  App for healthcare workers to fill out forms u...                                  ['W22', 'Active']     ['https://www.linkedin.com/company/voize-de/']   2020.0        4.0                    Berlin, Berlin, Germany; Remote                        Berlin, Germany  ['Fabio Schmidberger', 'Marcel Schmidberger', ...  [{'name': 'Fabio Schmidberger', 'role': '', 's...  voize is the digital voice assistant for non-d...
# 971                      Requestly                               https://requestly.io  Test & Debug Web and Mobile Applications for d...  ['W22', 'Active', 'Developer Tools', 'SaaS', '...  ['https://www.linkedin.com/company/requestly/'...   2021.0        4.0                       New Delhi, DL, India; Remote                       New Delhi, India                      ['Sachin Jain', 'Sagar Soni']  [{'name': 'Sachin Jain', 'role': '', 'social_m...  Requestly records all API traffic and allows d...
# 972                         Kaagaz                                 https://kaagaz.app  'Office' Suite for Mobile-first Businesses in ...                                  ['W22', 'Active']  ['https://www.linkedin.com/company/66964991/',...   2019.0        9.0                       Remote; New Delhi, DL, India                       New Delhi, India  ['Tamanjit Bindra', 'Snehanshu Gandhi', 'Gaura...  [{'name': 'Tamanjit Bindra', 'role': '', 'soci...  Kaagaz is an 'Office' Suite for Mobile-first B...
# 973                           Boya                                   https://boya.co/  Corporate Expense cards and Spend management f...  ['W22', 'Active', 'Fintech', 'FinOps', 'Neoban...  ['https://www.linkedin.com/company/boya-inc', ...   2021.0        9.0             Nairobi, Nairobi County, Kenya; Remote                         Nairobi, Kenya                ['Robert Nyangate', 'Alphas Sinja']  [{'name': 'Robert Nyangate', 'role': '', 'soci...  Boya Makes it easy for businesses in Africa to...
# 974                        Curacel                                 https://curacel.co                      Plaid for Insurance in Africa  ['W22', 'Active', 'Fintech', 'SaaS', 'B2B', 'A...  ['https://www.linkedin.com/company/curacel/', ...   2019.0       30.0                         Remote; Lagos, LA, Nigeria                         Lagos, Nigeria                                   ['Henry Mascot']  [{'name': 'John Flash Dada', 'role': 'Founder'...  One API to sell & process insurance across Afr...
# 975                         FinFlx                                 https://finflx.com           Flexible pension plans for SMEs in MENA.        ['W22', 'Active', 'Fintech', 'B2B', 'SaaS']  ['https://www.linkedin.com/company/finflx', 'h...   2021.0        8.0                Dubai, United Arab Emirates; Remote            Dubai, United Arab Emirates                 ['Amr Yussif', 'Matthieu Capelle']  [{'name': 'Amr Yussif', 'role': '', 'social_me...  FinFlx makes it easier and more affordable for...
# 976                        LunaJoy                            http://HelloLunaJoy.com             Precision mental health care for women  ['W22', 'Active', 'Mental Health Tech', 'Femte...  ['https://www.linkedin.com/company/lunajoy', '...   2021.0        6.0                           Remote; Atlanta, GA, USA                            Atlanta, GA                                    ['Shama Rathi']  [{'name': 'Sipra Laddha', 'role': 'Founder', '...  LunaJoy is a precision mental health platform ...
# 977                       Edustack                            https://www.edustack.ai                     OS for 100 Mn K-12 Classroooms             ['W22', 'Active', 'SaaS', 'Education']  ['https://www.linkedin.com/company/edustack-ai...   2021.0        7.0                Hyderabad, Telangana, India; Remote                       Hyderabad, India                                  ['Vamsee Koneru']  [{'name': 'Vamsee Koneru', 'role': '', 'social...  Edustack, is an EdTech SaaS platform. We are b...
# 978                         Cotera                                  https://cotera.co                          Find your best customers.                                  ['W22', 'Active']  ['https://www.linkedin.com/company/coterahq', ...   2021.0        2.0  Remote; New York, NY, USA; London, England, Un...                               New York                                      ['Tom Firth']  [{'name': 'Tom Firth', 'role': '', 'social_med...  Cotera is a prescriptive analytics platform th...
# 979                           Takt                             https://www.takt.tech/                         No-code workflow analytics  ['W22', 'Active', 'SaaS', 'B2B', 'No-code', 'A...  ['https://www.linkedin.com/company/takt-techno...   2021.0        2.0                           Remote; Chicago, IL, USA                            Chicago, IL                   ['Aditya Padwal', 'Jai Thirani']  [{'name': 'Aditya Padwal', 'role': '', 'social...  Takt is a no-code workflow analytics tool. If ...
# 980                          Botin                              https://www.botin.app             Investment super app for Latin America      ['W22', 'Active', 'Fintech', 'Crypto / Web3']  ['https://www.linkedin.com/company/botinapp', ...   2021.0        3.0    Remote; San José, San José Province, Costa Rica                   San José, Costa Rica  ['Robert Baron', 'James Jara', 'Federico Patiño']  [{'name': 'Robert Baron', 'role': '', 'social_...  Botin a mobile app where people in Latin Ameri...
# 981                           Posh                      https://www.poshrobotics.com/                    Automating EV battery recycling  ['W22', 'Active', 'ClimateTech', 'Robotics', '...  ['https://www.linkedin.com/company/posh-roboti...   2021.0        4.0                     San Francisco, CA, USA; Remote                          San Francisco               ['Minh Chung Hoang', 'Wesley Zheng']  [{'name': 'Minh Chung Hoang', 'role': '', 'soc...  Posh automates EV battery recycling. There are...
# 982                           Toko                             https://tokotutor.com/               Learn English by speaking with an AI  ['W22', 'Active', 'AI-Enhanced Learning', 'Edu...             ['https://www.facebook.com/tokotutor']   2021.0        2.0                                  New York, NY, USA                               New York                       ['Erica Du', 'Jennifer Liu']  [{'name': 'Erica Du', 'role': '', 'social_medi...  Toko helps English learners in East Asia achie...
# 983                      Enlightra                         https://www.enlightra.com/  Multicolor lasers for ultrafast data transmission         ['W22', 'Active', 'Hard Tech', 'Hardware']                                                 []   2021.0        4.0                          Ecublens, VD, Switzerland                  Ecublens, Switzerland                      ['John Jost', 'Maxim Karpov']  [{'name': 'John Jost', 'role': '', 'social_med...  Enlightra develops mass-manufacturable fingert...
# 984                         Cogram                                 https://cogram.com                     Query data without writing SQL                                  ['W22', 'Active']  ['https://www.linkedin.com/company/cogramai', ...   2021.0        2.0                    Berlin, Berlin, Germany; Remote                        Berlin, Germany                       ['Alexander von Boetticher']  [{'name': 'Ricardo Wölker', 'role': 'Founder',...  Cogram lets anybody query data without writing...
# 985            Markaz Technologies                             https://www.markaz.app  Reselling marketplace for social media entrepr...     ['W22', 'Active', 'E-commerce', 'Marketplace']  ['https://www.linkedin.com/company/markaz-tech...   2021.0        4.0  Islamabad, Islamabad Capital Territory, Pakist...                    Islamabad, Pakistan  ['Umair Aslam', 'Sameel Hayat', 'Shoaib Khan',...  [{'name': 'Umair Aslam', 'role': '', 'social_m...  We enable WhatsApp, Facebook, and Instagram-ba...
# 986                   Eazipay Inc.                              https://myeazipay.com                 Simple Payroll Solution for Africa  ['W22', 'Active', 'Fintech', 'Payroll', 'Payme...  ['https://www.linkedin.com/company/myeazipay/'...   2021.0        8.0                         Lagos, LA, Nigeria; Remote                         Lagos, Nigeria  ['Asher Adeniyi', 'Kingsley Michael', 'Efosa U...  [{'name': 'Asher Adeniyi', 'role': '', 'social...  We are Gusto for Africa. Eazipay is a simple, ...
# 987                         Wibond                             https://www.wibond.co/                                  Affirm for LATAM   ['W22', 'Active', 'Banking as a Service', 'Fin...                                                 []   2020.0       30.0                Córdoba, Cordoba, Argentina; Remote                     Córdoba, Argentina               ['Ezequiel Bucai', 'Lucrecia Porta']  [{'name': 'Ezequiel Bucai', 'role': '', 'socia...  Under "Buy Now, Pay Later" business model, Wib...
# 988                       Snippyly                               https://snippyly.com  APIs to make your app multiplayer, just like F...  ['W22', 'Active', 'SaaS', 'Collaboration', 'Re...  ['https://www.linkedin.com/company/snippyly/',...   2020.0        4.0                     Remote; San Francisco, CA, USA                          San Francisco                                   ['Rakesh Goyal']  [{'name': 'Rakesh Goyal', 'role': '', 'social_...  With Snippyly APIs, developers can make their ...
# 989                   digiventures                       https://www.digiventures.la/  Enabling banks have a fintech-style loan origi...        ['W22', 'Active', 'Fintech', 'SaaS', 'B2B']  ['https://www.linkedin.com/company/digiventure...   2018.0       30.0              Buenos Aires, CABA, Argentina; Remote                Buenos Aires, Argentina         ['Hernan Lopez Conde', 'Santiago Pezzoni']  [{'name': 'Hernan Lopez Conde', 'role': '', 's...  Digiventures SaaS enables banks in Latin Ameri...
# 990                       PayCaddy                              https://paycaddy.com/          Simplified Banking as a Service for Latam  ['W22', 'Active', 'Fintech', 'B2B', 'Banking a...  ['https://www.linkedin.com/company/65344002/ad...   2018.0       14.0                Panama City, Panama, Panama; Remote                    Panama City, Panama        ['Juan Diego Galvez', 'Federico Benavides']  [{'name': 'Juan Diego Galvez', 'role': '', 'so...  PayCaddy enables Latam companies to launch fin...
# 991                    Tuva Health                            https://tuvahealth.com/  Open source software that cleans and transform...  ['W22', 'Active', 'SaaS', 'Digital Health', 'B...  ['https://www.linkedin.com/company/tuva-health/']   2021.0        3.0                    Remote; Salt Lake City, UT, USA                     Salt Lake City, UT              ['Coco Zuloaga', 'Aaron Neiderhiser']  [{'name': 'Coco Zuloaga', 'role': '', 'social_...  At Tuva Health, we make open source software t...
# 992                        Plumter                                https://plumter.com                   Easy foreign payments for Africa                       ['W22', 'Active', 'Fintech']  ['https://www.linkedin.com/company/plumter', '...   2021.0        2.0                         Remote; Lagos, LA, Nigeria                         Lagos, Nigeria                    ['Yinka Elujoba', 'Eni Joshua']  [{'name': 'Yinka Elujoba', 'role': '', 'social...  We're providing payment rails and APIs to help...
# 993                       Complete                                https://complete.so                The complete way to do compensation        ['W22', 'Active', 'HR Tech', 'SaaS', 'B2B']  ['https://www.linkedin.com/company/withcomplet...   2021.0        2.0                             San Francisco, CA, USA                          San Francisco                      ['Zack Field', 'Rani Mavram']  [{'name': 'Zack Field', 'role': '', 'social_me...  The complete way to communicate compensation, ...
# 994                          Tingo                                 https://mytingo.io          Android phone dialer app for young people  ['W22', 'Active', 'Social', 'Consumer', 'Enter...   ['https://www.linkedin.com/company/tingo-tech/']   2021.0        2.0                        Remote; Gurugram, HR, India                        Gurugram, India               ['Sandilya Miduthuri', 'Chalam PVS']  [{'name': 'Sandilya Miduthuri', 'role': '', 's...  Tingo is an android dialer app for young peopl...
# 995                          Anfin                                  https://anfin.vn/                   Modern stock trading for Vietnam  ['W22', 'Active', 'Fintech', 'Investing', 'Con...  ['https://www.linkedin.com/company/anfin-vn/my...   2021.0       40.0        Ho Chi Minh City, Ho Chi Minh City, Vietnam              Ho Chi Minh City, Vietnam                       ['Michael Do', 'Phuoc Tran']  [{'name': 'Michael Do', 'role': '', 'social_me...  Anfin is building a modern trading experience ...
# 996                   InsureMyTeam                       https://www.insuremyteam.com  Disrupting Indian Insurance space by empowerin...  ['W22', 'Active', 'Health Insurance', 'Healthc...                                                 []   2021.0       11.0                                  MH, India; Remote                          Mumbai, India                     ['Kunal Popat', 'Rachit Puri']  [{'name': 'Kunal Popat', 'role': '', 'social_m...  India’s insurance market is filled with bygone...
# 997                           SALT                                    https://salt.pe     B2B Cross-Border Payment & Compliance Platform        ['W22', 'Active', 'Fintech', 'B2B', 'SaaS']  ['https://www.linkedin.com/company/saltpe/', '...   2020.0       14.0                       Bengaluru, KA, India; Remote                       Bengaluru, India                    ['Udita Pal', 'Ankit Parasher']  [{'name': 'Udita Pal', 'role': '', 'social_med...  Salt is a neo banking solution stitched togeth...
# 998                       NearWave                                 http://nearwave.co  Helping physicians select the right therapy fo...  ['W22', 'Active', 'Healthcare', 'Medical Devic...  ['https://www.linkedin.com/company/nearwave/ab...   2020.0        1.0                        South Bend, IN, USA; Remote                         South Bend, IN                                  ['Roy Stillwell']  [{'name': 'Roy Stillwell', 'role': '', 'social...  NearWave makes a handheld imaging device that ...
# 999               Stairs Financial                        https://stairsfinancial.com                Find a home you can actually afford  ['W22', 'Active', 'Fintech', 'Proptech', 'GovT...  ['https://www.linkedin.com/company/stairs-fina...   2021.0        2.0                          New York, NY, USA; Remote                               New York             ['Malcolm-Wiley Floyd', 'Scott Fritz']  [{'name': 'Malcolm-Wiley Floyd', 'role': '', '...  Stairs helps young Americans buy their first h...
